# %%
# !pip install yfinance
# Out:
# Collecting yfinance
#   Obtaining dependency information for yfinance from https://files.pythonhosted.org/packages/e9/43/93ea65227c938a0a4a8925d7f054b050ea743044b887170da9eca210635a/yfinance-0.2.28-py2.py3-none-any.whl.metadata
#   Downloading yfinance-0.2.28-py2.py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: pandas>=1.3.0 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from yfinance) (1.5.3)
# Requirement already satisfied: numpy>=1.16.5 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from yfinance) (1.23.5)
# Collecting requests>=2.31 (from yfinance)
#   Obtaining dependency information for requests>=2.31 from https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl.metadata
#   Using cached requests-2.31.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting multitasking>=0.0.7 (from yfinance)
#   Downloading multitasking-0.0.11-py3-none-any.whl (8.5 kB)
# Requirement already satisfied: lxml>=4.9.1 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from yfinance) (4.9.1)
# Collecting appdirs>=1.4.4 (from yfinance)
#   Downloading appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting pytz>=2022.5 (from yfinance)
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting frozendict>=2.3.4 (from yfinance)
#   Downloading frozendict-2.3.8-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (115 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 115.3/115.3 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: beautifulsoup4>=4.11.1 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from yfinance) (4.11.1)
# Collecting html5lib>=1.1 (from yfinance)
#   Downloading html5lib-1.1-py2.py3-none-any.whl (112 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 112.2/112.2 kB 11.8 MB/s eta 0:00:00
# Requirement already satisfied: soupsieve>1.2 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from beautifulsoup4>=4.11.1->yfinance) (2.3.2.post1)
# Requirement already satisfied: six>=1.9 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (1.16.0)
# Requirement already satisfied: webencodings in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from html5lib>=1.1->yfinance) (0.5.1)
# Requirement already satisfied: python-dateutil>=2.8.1 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from pandas>=1.3.0->yfinance) (2.8.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2.1.1)
# Requirement already satisfied: idna<4,>=2.5 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from requests>=2.31->yfinance) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from requests>=2.31->yfinance) (1.26.12)
# Requirement already satisfied: certifi>=2017.4.17 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from requests>=2.31->yfinance) (2022.9.24)
# Downloading yfinance-0.2.28-py2.py3-none-any.whl (65 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 65.3/65.3 kB 10.7 MB/s eta 0:00:00
# Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Installing collected packages: pytz, multitasking, appdirs, requests, html5lib, frozendict, yfinance
#   Attempting uninstall: pytz
#     Found existing installation: pytz 2022.1
#     Uninstalling pytz-2022.1:
#       Successfully uninstalled pytz-2022.1
#   Attempting uninstall: requests
#     Found existing installation: requests 2.28.1
#     Uninstalling requests-2.28.1:
#       Successfully uninstalled requests-2.28.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# lovelace 0.0.7 requires tensorflow==2.10.0; sys_platform != "darwin", but you have tensorflow 2.13.0 which is incompatible.
# pandas-gbq 0.17.9 requires pyarrow<10.0dev,>=3.0.0, but you have pyarrow 10.0.1 which is incompatible.
# pandas-profiling 3.3.0 requires joblib~=1.1.0, but you have joblib 1.3.2 which is incompatible.
# pandas-profiling 3.3.0 requires pandas!=1.4.0,<1.5,>1.1, but you have pandas 1.5.3 which is incompatible.
# pandas-profiling 3.3.0 requires requests<2.29,>=2.24.0, but you have requests 2.31.0 which is incompatible.
# pandas-profiling 3.3.0 requires scipy<1.10,>=1.4.1, but you have scipy 1.10.0 which is incompatible.
# Successfully installed appdirs-1.4.4 frozendict-2.3.8 html5lib-1.1 multitasking-0.0.11 pytz-2023.3 requests-2.31.0 yfinance-0.2.28

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (3.5.3)
# Requirement already satisfied: cycler>=0.10 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (4.38.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.17 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (1.23.5)
# Requirement already satisfied: packaging>=20.0 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (9.1.1)
# Requirement already satisfied: pyparsing>=2.2.1 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: six>=1.5 in /home/fede/.pyenv/versions/3.10.6/envs/default/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)

# %%
import pandas as pd
import yfinance as yf
import matplotlib.pyplot as plt

pd.options.display.float_format = '{:,.2f}'.format


# berkshire hathaway inc. (b stock)


ypf_finance = yf.Ticker('ypf')
hist_preestatizacion = ypf_finance.history(start='2000-01-01', end='2022-08-24', auto_adjust=True)

# %%
hist_preestatizacion.reset_index(inplace=True)
hist_preestatizacion['Year'] = hist_preestatizacion['Date'].dt.year
hist_preestatizacion['Month'] = hist_preestatizacion['Date'].dt.month
hist_preestatizacion = hist_preestatizacion.reindex(columns=['Year','Month','Date','Open','High','Low','Close', 'Volume','Dividends']) #Saque "Stock Splits", todos los valores = 0"
hist_preestatizacion
# Out:
#       Year  Month                      Date  Open  High   Low  Close   Volume  \
# 0     2000      1 2000-01-03 00:00:00-05:00 11.65 11.65 11.49  11.53    52400
# 1     2000      1 2000-01-04 00:00:00-05:00 11.47 11.47 11.43  11.45    18300
# 2     2000      1 2000-01-05 00:00:00-05:00 11.37 11.59 11.31  11.51    42000
# 3     2000      1 2000-01-06 00:00:00-05:00 11.47 11.47 11.35  11.43     6400
# 4     2000      1 2000-01-07 00:00:00-05:00 11.39 11.67 11.37  11.55     8800
# ...    ...    ...                       ...   ...   ...   ...    ...      ...
# 5692  2022      8 2022-08-17 00:00:00-04:00  4.61  4.72  4.50   4.64  2434100
# 5693  2022      8 2022-08-18 00:00:00-04:00  4.65  4.94  4.65   4.85  2554100
# 5694  2022      8 2022-08-19 00:00:00-04:00  4.79  4.79  4.61   4.65  1595400
# 5695  2022      8 2022-08-22 00:00:00-04:00  4.59  4.86  4.47   4.77  2282600
# 5696  2022      8 2022-08-23 00:00:00-04:00  4.84  5.21  4.81   5.17  5211000
#
#       Dividends
# 0          0.00
# 1          0.00
# 2          0.00
# 3          0.00
# 4          0.00
# ...         ...
# 5692       0.00
# 5693       0.00
# 5694       0.00
# 5695       0.00
# 5696       0.00
#
# [5697 rows x 9 columns]

# %%
hist_preestatizacion = hist_preestatizacion.groupby(['Year','Month']).agg({'Close': max})
hist_preestatizacion.plot(figsize=(15,10))
# Out:
# <AxesSubplot:xlabel='Year,Month'>
