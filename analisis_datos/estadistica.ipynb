# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import seaborn as sns
from statistics import NormalDist

# %%
male_df = pd.DataFrame([140, 145, 160, 190, 155, 165, 150, 190, 195, 138, 160, 155, 153, 145, 170, 175, 175, 170, 180, 135,
170, 157, 130, 185, 190, 155, 170, 155, 215, 150, 145, 155, 155, 150, 155, 150, 180, 160, 135, 160, 130, 155, 150, 148, 155,
150, 140, 180, 190, 145, 150, 164, 140, 142, 136, 123, 155],
 columns=['weight'])

# %%
male_df['sex'] = 'male'
female_df = pd.DataFrame([140, 120, 130, 138, 121, 116, 125, 145, 150, 112, 125, 130, 120, 130, 131, 120, 118, 125, 135, 125,
118, 122, 115, 102, 115, 150, 110, 116, 108, 95, 125, 133, 110, 150, 108],
 columns=['weight'])
female_df['sex'] = 'female'

# %%
weights_df = pd.concat([male_df, female_df], ignore_index=True) # me arma uno entero con 2 df’s concatenados siempre y cuando los valores sean los mismos
weights_df.sample(5)
# Out:
#     weight     sex
# 52     140    male
# 19     135    male
# 41     155    male
# 76     125  female
# 2      160    male

# %% [markdown]
# ___

# %% [markdown]
# # Histograma

# %%
ax = sns.histplot(weights_df["weight"], bins=len(weights_df))
ax.set_xlabel("Weight (in lbs)")
plt.show()

# bins: cantidad de barras
# ax: eje x

# %% [markdown]
# ### → Un histograma es una representación precisa de la distribución de datos numéricos.
# ### → Es una estimación de la distribución de probabilidad de una variable continua.

# %% [markdown]
# ___

# %% [markdown]
# # Histogram Bins

# %%
f, (ax1, ax2, ax3) = plt.subplots(1, 3, figsize=(15, 4))
ax1.hist(weights_df["weight"], bins=[95, 105, 115, 125, 135, 145, 155, 165, 175, 185, 195, 205, 215])
ax2.hist(weights_df["weight"], bins=12)
sns.histplot(weights_df["weight"], bins=12, ax=ax3, kde=True)
plt.show()

# %% [markdown]
# ___

# %% [markdown]
# # Cumulative Plots

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(15, 4))
ax1.hist(weights_df["weight"], bins=25, cumulative=True, density=True)
sns.histplot(weights_df["weight"], binwidth=5, ax=ax2, kde=True,
 cumulative=True, stat="percent");

# %% [markdown]
# ### → Alternativamente, podemos trazar el recuento de pesos inferiores a un determinado valor.
# ### → En lugar de los recuentos, también podemos trazar la densidad (sumas hasta 1) o el porcentaje (sumas hasta 100).

# %% [markdown]
# ___

# %% [markdown]
# # Box Plot

# %%
sns.boxplot(x=weights_df["weight"])
plt.show()

# %% [markdown]
# ### INTERQUARTILE RANGE (IQR) = Q3 - Q1
#
# ### → Definición de outlier: Valores anómalos/atípicos (la mediana es robusta contra los outliers)
# ### → En este caso se puede ver que hay un outlier en este boxplot, es 220.

# %% [markdown]
# ___

# %% [markdown]
# # Summary Statistics

# %%
weights_df.describe()
# Out:
#            weight
# count   92.000000
# mean   145.152174
# std     23.739398
# min     95.000000
# 25%    125.000000
# 50%    145.000000
# 75%    155.500000
# max    215.000000

# %% [markdown]
# ___

# %% [markdown]
# # Normal Distribution

# %%
NormalDist(mu=100, sigma=12).pdf(98)
# Out:
# 0.032786643008494994
