# %% [markdown]
# # Ejercicio manejo de faltantes
#
# Cargar el archivo "Building_Permits.csv"

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df_building= pd.read_csv("/Users/lolonastri/Desktop/POO_UCEMA/machine_learning/3-manejo_faltantes/practica/Building_Permits.csv")
# Out:
# /var/folders/xx/hcklcr8s0rxd7p5fz63z342w0000gn/T/ipykernel_94681/3172117188.py:5: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   df_building= pd.read_csv("/Users/lolonastri/Desktop/POO_UCEMA/machine_learning/3-escalado_normalizacion/taller faltantes/Building_Permits.csv")

# %% [markdown]
# ___

# %% [markdown]
# # 1) Echar un primer vistazo a los datos
#
# Complete la siguiente celda de código para cargar el conjunto de datos que utilizará para completar el ejercicio.

# %%
df_building
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %% [markdown]
# Utilice la siguiente celda de código para imprimir las primeras cinco filas del conjunto de datos

# %%
df_building.head(5)
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %% [markdown]
# ¿Al conjunto de datos le faltan valores?

# %%
df_building.isnull().sum()
# Out:
# Permit Number                                  0
# Permit Type                                    0
# Permit Type Definition                         0
# Permit Creation Date                           0
# Block                                          0
# Lot                                            0
# Street Number                                  0
# Street Number Suffix                      196684
# Street Name                                    0
# Street Suffix                               2768
# Unit                                      169421
# Unit Suffix                               196939
# Description                                  290
# Current Status                                 0
# Current Status Date                            0
# Filed Date                                     0
# Issued Date                                14940
# Completed Date                            101709
# First Construction Document Date           14946
# ...

# %% [markdown]
# ___

# %% [markdown]
# # 2) ¿Cuántos puntos de datos faltantes tenemos?
# ¿Qué porcentaje de los valores del conjunto de datos faltan? Su respuesta debe ser un número entre 0 y 100. (Si falta 1/4 de los valores en el conjunto de datos, la respuesta es 25).

# %%
df_building.isnull().sum()/len(df_building)*100
# Out:
# Permit Number                              0.000000
# Permit Type                                0.000000
# Permit Type Definition                     0.000000
# Permit Creation Date                       0.000000
# Block                                      0.000000
# Lot                                        0.000000
# Street Number                              0.000000
# Street Number Suffix                      98.885872
# Street Name                                0.000000
# Street Suffix                              1.391654
# Unit                                      85.178984
# Unit Suffix                               99.014077
# Description                                0.145802
# Current Status                             0.000000
# Current Status Date                        0.000000
# Filed Date                                 0.000000
# Issued Date                                7.511312
# Completed Date                            51.135747
# ...

# %% [markdown]
# ___

# %% [markdown]
# # 3) Descubra por qué faltan datos
#
# Mire las columnas **"Street Number Suffix"** y **"Zipcode"** del [conjunto de datos de permisos de construcción de San Francisco]. Ambos contienen valores faltantes.
# - ¿Cuáles, en su caso, faltan porque no existen?
# - ¿Cuáles, en su caso, faltan porque no fueron grabados?

# %%
df_building["Street Number Suffix"].value_counts() # La direccion no tiene que tener un sufijo obligatoriamente
# Out:
# Street Number Suffix
# A    1501
# B     291
# V     228
# C      56
# E      28
# F      24
# G      12
# D      11
# K      11
# H      11
# L      10
# R      10
# J       9
# I       7
# P       3
# N       2
# 0       1
# ½       1
# Name: count, dtype: int64

# %%
df_building["Zipcode"].value_counts() # No es relevante el codigo postal en este instante ya que el 'Zipcode' y 'Street Name' / 'Street Number' nos dan exactamente la misma información en caso de querer predecir algo.
# Out:
# Zipcode
# 94110.0    17837
# 94114.0    13404
# 94117.0    11780
# 94109.0    11348
# 94103.0    10986
# 94115.0    10095
# 94118.0     9812
# 94123.0     9515
# 94122.0     8886
# 94105.0     8628
# 94112.0     7897
# 94121.0     7773
# 94107.0     7706
# 94131.0     7664
# 94133.0     7424
# 94102.0     7164
# 94116.0     6421
# 94111.0     5385
# 94108.0     5320
# 94124.0     5265
# 94127.0     4993
# 94104.0     4229
# 94132.0     3507
# 94134.0     2983
# 94158.0     1058
# 94130.0       81
# 94129.0       23
# Name: count, dtype: int64

# %%
df_building[df_building.isna().any(axis=1)]
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...

# %% [markdown]
# ___

# %% [markdown]
# # 4) Eliminar los valores faltantes: filas
#
# Si eliminó todas las filas de "data" con valores faltantes, ¿cuántas filas quedan?
#
# **Nota**: No cambie el valor de "data" al verificar esto.

# %%
df_building.dropna(axis=0) # como no hay que cambiar el valor de la data para verificar esto, no lo igualo a ninguna variable.
# Out:
# Empty DataFrame
# Columns: [Permit Number, Permit Type, Permit Type Definition, Permit Creation Date, Block, Lot, Street Number, Street Number Suffix, Street Name, Street Suffix, Unit, Unit Suffix, Description, Current Status, Current Status Date, Filed Date, Issued Date, Completed Date, First Construction Document Date, Structural Notification, Number of Existing Stories, Number of Proposed Stories, Voluntary Soft-Story Retrofit, Fire Only Permit, Permit Expiration Date, Estimated Cost, Revised Cost, Existing Use, Existing Units, Proposed Use, Proposed Units, Plansets, TIDF Compliance, Existing Construction Type, Existing Construction Type Description, Proposed Construction Type, Proposed Construction Type Description, Site Permit, Supervisor District, Neighborhoods - Analysis Boundaries, Zipcode, Location, Record ID]
# Index: []
#
# [0 rows x 43 columns]

# %%
print(" El dataset tiene " + str(df_building.dropna(axis=0).shape[1]) + " columnas.")
# Out:
#  El dataset tiene 43 columnas

# %% [markdown]
# ___

# %% [markdown]
# # 5) Eliminar los valores faltantes: columnas
#
# Ahora intente eliminar todas las columnas con valores vacíos.
# - Cree un nuevo DataFrame llamado `data_with_na_dropped` que tenga todas las columnas con valores vacíos eliminados.
# - ¿Cuántas columnas se eliminaron del DataFrame original? Utilice este número para establecer el valor de la variable `dropped_columns` a continuación.

# %%
data_with_na_dropped = df_building.dropna(axis=1)
data_with_na_dropped
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Name  \
# 0                05/06/2015  0326   023            140       Ellis
# ...

# %%
print(" El dataset tiene " + str(data_with_na_dropped.shape[1]) + " columnas.")
# Out:
#  El dataset tiene 12 columnas.

# %%
dropped_columns = df_building.dropna(axis=0).shape[1] - data_with_na_dropped.shape[1]
dropped_columns
# Out:
# 31

# %% [markdown]
# ___

# %% [markdown]
# # 6) Complete los valores faltantes automáticamente
#
# Intente reemplazar todos los NaN en los datos con el que viene directamente después y luego reemplace los NaN restantes con 0. Establezca el resultado en un nuevo DataFrame `data_with_na_imputed`.

# %%
data_with_na_imputed = df_building.fillna(method='bfill', axis=0).fillna(0)
data_with_na_imputed
# Out:
#        Permit Number  Permit Type            Permit Type Definition  \
# 0       201505065519            4                      sign - erect
# 1       201604195146            4                      sign - erect
# 2       201605278609            3  additions alterations or repairs
# 3       201611072166            8            otc alterations permit
# 4       201611283529            6                       demolitions
# ...              ...          ...                               ...
# 198895       M862628            8            otc alterations permit
# 198896  201712055595            8            otc alterations permit
# 198897       M863507            8            otc alterations permit
# 198898       M863747            8            otc alterations permit
# 198899       M864287            8            otc alterations permit
#
#        Permit Creation Date Block   Lot  Street Number Street Number Suffix  \
# ...
