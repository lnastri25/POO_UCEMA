# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
df = pd.read_csv("/Users/lolonastri/Desktop/POO_UCEMA/trabajos_practicos/trabajo_practico_0/sharks/attracks.csv", encoding= "latin-1")
df = df.drop(columns = ["Unnamed: 22", "Unnamed: 23", "pdf", "href formula", "href", "Case Number.1", "Case Number.2", "original order", "Case Number"])
df
# Out:
#              Date  Year        Type             Country               Area  \
# 0       18-Sep-16  2016  Unprovoked                 USA            Florida
# 1       18-Sep-16  2016  Unprovoked                 USA            Florida
# 2       18-Sep-16  2016  Unprovoked                 USA            Florida
# 3       17-Sep-16  2016  Unprovoked           AUSTRALIA           Victoria
# 4       16-Sep-16  2016  Unprovoked           AUSTRALIA           Victoria
# ...           ...   ...         ...                 ...                ...
# 5987  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5988  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5989    1900-1905     0  Unprovoked                 USA     North Carolina
# 5990    1883-1889     0  Unprovoked              PANAMA                NaN
# 5991    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# ...

# %%
df.columns.values
# Out:
# array(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source'], dtype=object)

# %%
df.shape
# Out:
# (5992, 15)

# %%
df.shape[0] # Cantidad de filas
# Out:
# 5992

# %%
df.shape[1] # Cantidad de columnas
# Out:
# 15

# %%
df.head(10)
# Out:
#         Date  Year        Type        Country               Area  \
# 0  18-Sep-16  2016  Unprovoked            USA            Florida
# 1  18-Sep-16  2016  Unprovoked            USA            Florida
# 2  18-Sep-16  2016  Unprovoked            USA            Florida
# 3  17-Sep-16  2016  Unprovoked      AUSTRALIA           Victoria
# 4  16-Sep-16  2016  Unprovoked      AUSTRALIA           Victoria
# 5  15-Sep-16  2016        Boat      AUSTRALIA  Western Australia
# 6  11-Sep-16  2016  Unprovoked            USA            Florida
# 7  07-Sep-16  2016  Unprovoked            USA             Hawaii
# 8  06-Sep-16  2016  Unprovoked  NEW CALEDONIA     North Province
# 9  05-Sep-16  2016  Unprovoked            USA     South Carolina
#
#                                           Location         Activity  \
# 0                 New Smyrna Beach, Volusia County          Surfing
# 1                 New Smyrna Beach, Volusia County          Surfing
# ...

# %%
df.tail()
# Out:
#              Date  Year        Type             Country               Area  \
# 5987  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5988  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5989    1900-1905     0  Unprovoked                 USA     North Carolina
# 5990    1883-1889     0  Unprovoked              PANAMA                NaN
# 5991    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# 5987                          Roebuck Bay        Diving
# 5988                                  NaN  Pearl diving
# 5989                       Ocracoke Inlet      Swimming
# 5990                 Panama Bay 8ºN, 79ºW           NaN
# 5991  Below the English fort, Trincomalee      Swimming
#
#                        Name Sex   Age  \
# 5987                   male    M  NaN
# 5988                  Ahmun    M  NaN
# 5989  Coast Guard personnel    M  NaN
# ...

# %%
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species ',
#        'Investigator or Source'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5992 entries, 0 to 5991
# Data columns (total 15 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Date                    5992 non-null   object
#  1   Year                    5992 non-null   int64
#  2   Type                    5992 non-null   object
#  3   Country                 5949 non-null   object
#  4   Area                    5590 non-null   object
#  5   Location                5496 non-null   object
#  6   Activity                5465 non-null   object
#  7   Name                    5792 non-null   object
#  8   Sex                     5425 non-null   object
#  9   Age                     3311 non-null   object
#  10  Injury                  5965 non-null   object
#  11  Fatal (Y/N)             5973 non-null   object
#  12  Time                    2779 non-null   object
#  13  Species                 3058 non-null   object
# ...

# %%
df.isna().sum()
# Out:
# Date                         0
# Year                         0
# Type                         0
# Country                     43
# Area                       402
# Location                   496
# Activity                   527
# Name                       200
# Sex                        567
# Age                       2681
# Injury                      27
# Fatal (Y/N)                 19
# Time                      3213
# Species                   2934
# Investigator or Source      15
# dtype: int64

# %%
df.isna().sum()/len(df)
# Out:
# Date                      0.000000
# Year                      0.000000
# Type                      0.000000
# Country                   0.007176
# Area                      0.067089
# Location                  0.082777
# Activity                  0.087951
# Name                      0.033378
# Sex                       0.094626
# Age                       0.447430
# Injury                    0.004506
# Fatal (Y/N)               0.003171
# Time                      0.536215
# Species                   0.489653
# Investigator or Source    0.002503
# dtype: float64

# %%
df.rename(columns = {"Date": "Dia", "Year" : "Año"}) # Renombrado de columnas
# Out:
#               Dia   Año        Type             Country               Area  \
# 0       18-Sep-16  2016  Unprovoked                 USA            Florida
# 1       18-Sep-16  2016  Unprovoked                 USA            Florida
# 2       18-Sep-16  2016  Unprovoked                 USA            Florida
# 3       17-Sep-16  2016  Unprovoked           AUSTRALIA           Victoria
# 4       16-Sep-16  2016  Unprovoked           AUSTRALIA           Victoria
# ...           ...   ...         ...                 ...                ...
# 5987  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5988  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5989    1900-1905     0  Unprovoked                 USA     North Carolina
# 5990    1883-1889     0  Unprovoked              PANAMA                NaN
# 5991    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#                                  Location      Activity  \
# ...

# %%
df["Species "].value_counts()
# Out:
# Species
# White shark                                                                                                                      161
# Shark involvement not confirmed                                                                                                   80
# Tiger shark                                                                                                                       68
# Bull shark                                                                                                                        52
# 6' shark                                                                                                                          40
#                                                                                                                                 ...
# Thought to involve a white, bull or tiger shark                                                                                    1
# ...

# %%
df["Species "] == "White shark"
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5987    False
# 5988    False
# 5989    False
# 5990    False
# 5991    False
# Name: Species , Length: 5992, dtype: bool

# %%
white_shark_ataques = df[(df["Sex "] == "F") & (df["Species "] == "White Shark")].value_counts()
white_shark_ataques
# Out:
# Series([], Name: count, dtype: int64)

# %%
df.columns = df.columns.str.strip()
df.columns
# Out:
# Index(['Date', 'Year', 'Type', 'Country', 'Area', 'Location', 'Activity',
#        'Name', 'Sex', 'Age', 'Injury', 'Fatal (Y/N)', 'Time', 'Species',
#        'Investigator or Source'],
#       dtype='object')

# %%
# american_filter = df["Region"].str.contains("EUR") trame solamente los de la region que contengan la palabra EUR.
