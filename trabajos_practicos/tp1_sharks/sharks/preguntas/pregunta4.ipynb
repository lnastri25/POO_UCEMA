# %%
import pandas as pd

# %%
tiburones4 = pd.read_csv("/Users/lolonastri/Desktop/POO_UCEMA/trabajos_practicos/trabajo_practico_0/sharks/attracks.csv", encoding= "latin-1")
tiburones4 = tiburones4.drop(columns = ["Unnamed: 22", "Unnamed: 23", "pdf", "href formula", "href", "Case Number.1", "Case Number.2", "original order", "Case Number", "Investigator or Source", "Location", "Name", "Time"])
tiburones4
# Out:
#              Date  Year        Type             Country               Area  \
# 0       18-Sep-16  2016  Unprovoked                 USA            Florida
# 1       18-Sep-16  2016  Unprovoked                 USA            Florida
# 2       18-Sep-16  2016  Unprovoked                 USA            Florida
# 3       17-Sep-16  2016  Unprovoked           AUSTRALIA           Victoria
# 4       16-Sep-16  2016  Unprovoked           AUSTRALIA           Victoria
# ...           ...   ...         ...                 ...                ...
# 5987  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5988  Before 1903     0  Unprovoked           AUSTRALIA  Western Australia
# 5989    1900-1905     0  Unprovoked                 USA     North Carolina
# 5990    1883-1889     0  Unprovoked              PANAMA                NaN
# 5991    1845-1853     0  Unprovoked  CEYLON (SRI LANKA)   Eastern Province
#
#           Activity Sex   Age  \
# 0          Surfing    M   16
# ...

# %% [markdown]
# ___

# %% [markdown]
# # 4) ¿Cuántas mujeres fueron atacadas por tiburones blancos?

# %%
tipo_de_ataque = tiburones4[tiburones4["Species "] == 'White shark'][tiburones4["Sex "] == 'F'] 
# tipo_de_ataque.count()
tipo_de_ataque["Fatal (Y/N)"].count()
# Out:
# /var/folders/xx/hcklcr8s0rxd7p5fz63z342w0000gn/T/ipykernel_78181/2859577031.py:1: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   tipo_de_ataque = tiburones4[tiburones4["Species "] == 'White shark'][tiburones4["Sex "] == 'F']
# 9

# %% [markdown]
# ___

# %% [markdown]
#     ➢ Conclusión:
#
#     Podemos observar que la cantidad de mujeres afectadas por un tiburón blanco o 'White Shark' es de 9.

# %% [markdown]
# ___

# %% [markdown]
#     ➢ Con respecto a la pregunta número 4, pudimos identificar 1 tipo de sesgo:
#
#     1) Sesgo de selección: Al considerar solo ataques de tiburones blancos, lo que sucede es que se está excluyendo a otras especies de tiburones que también podrían haber realizado ataques. Esto podría dar la impresión de que los tiburones blancos son los únicos culpables de los ataques. Además, al solo considerar como género a las mujeres, se podría llegar a pensar que los tiburones blancos solamente atacan mujeres, pero no es el caso.
